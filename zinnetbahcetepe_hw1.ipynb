# %% [markdown]
# ZİNNET BAHÇETEPE / HOMEWORK-1

# %% [markdown]
# ##Problem

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
matrx0=list(range(9))

matrx1 = [i+1 for i in matrx0 if i<=2]

matrx2 = [i+2 for i in matrx0 if i>2 and i% 2 == 1]

matrx3 = [i for i in matrx0 if i<7 and i% 2 == 1 ]   

print(matrx1)
print(matrx2)
print(matrx3)
# Out:
# [1, 2, 3]
# [5, 7, 9]
# [1, 3, 5]
