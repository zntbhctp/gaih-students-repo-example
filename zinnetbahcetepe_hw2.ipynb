# %% [markdown]
# ZİNNET BAHÇETEPE / HOMEWORK-2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Öğrenci Listesi
ogrenciler= ["Duygu Irmak", "Deniz Doğru", "Ali Uslu", "Özge Sucu", "Mine Tuzcu"]

#OrtalamaHesapla
ortNot1 = (80 + 62 + 74) / 3

ortNot2 = (62 + 78 + 70) / 3

ortNot3 = (50 + 62 + 74) / 3

ortNot4 = (92 + 68 + 86) / 3

ortNot5= (42 + 60 + 33) / 3


Information = {"Duygu Irmak":ortNot1, "Deniz Doğru": ortNot2, "Ali Uslu": ortNot3, "Özge Sucu": ortNot4, 
               "Mine Tuzcu":ortNot5}



print(Information)


Ortalamalar = [ortNot1, ortNot2, ortNot3, ortNot4, ortNot5]
MaxOrtalama = max(Ortalamalar)
print(Ortalamalar.index(MaxOrtalama))
print("Tebrikler! " +  ogrenciler[Ortalamalar.index(MaxOrtalama)])
# Out:
# {'Duygu Irmak': 72.0, 'Deniz Doğru': 70.0, 'Ali Uslu': 62.0, 'Özge Sucu': 82.0, 'Mine Tuzcu': 45.0}
# 3
# Tebrikler! Özge Sucu

# %%
""""Hocam çözene kadar çok uğraştım ve aşağıdaki uğraşı silmeye kıyamadım :) Aslında Input girilerek yapmayı denedim ama 
şimdilik yetiştiremedim, tam olarak istediğiniz bu değil aslında 
ama kafam çok karıştı, diğer ödevleri de yetiştirebilmek için burada bırakıyorum""""

# %%
#Öğrenci Bilgileri
Ogr1 = ["Duygu Irmak"]
Ogr2 = ["Deniz Doğru"]
Ogr3 = ["Ali Uslu"]
Ogr4  = ["Özge Sucu"]
Ogr5  = ["Mine Tuzcu"]


#Öğrenci Not Bilgisi
Not1 = [80, 62, 75]
Not2 = [62, 78, 80]
Not3 = [50, 62, 75]
Not4 = [92, 88, 86]
Not5 = [42, 67, 34]

Information = {"Duygu Irmak": Not1, "Deniz Doğru": Not2, "Ali Uslu": Not3, "Özge Sucu": Not4, 
               "Mine Tuzcu": Not5}


for i in Information:
    if i:3 > max:
            print("Congrats!" + Information.keys() )
    
  ##  print("Congrats!" + str(ortlm.max in Information )
# Out:
#   File "<ipython-input-10-8803d8362ad1>", line 21
#     if i:3 > max:
#                  ^
# SyntaxError: invalid syntax

# %%
start_number = int(input("Please enter a start number: "))

if 0 <= start_number <= 100:
  stop_number = int(input("Please enter a stop number: "))

# %%
#Öğrenciler
Ogr1 = ["Duygu Irmak"]
Ogr2 = ["Deniz Doğru"]
Ogr3 = ["Ali Uslu"]
Ogr4 = ["Özge Sucu"]
Ogr5 = ["Mine Tuzcu"]

#Not Bilgisi
NotList = [Midtern, Final, Homework]
Midtern, Final, Homework = float(input("Notlarınızı Giriniz!"))


Information = {"Duygu Irmak": Ogr1, "Deniz Doğru": Ogr2, "Ali Uslu": Ogr3, "Özge Sucu": Ogr4, "Mine Tuzcu": Ogr5}

for v in Information.values():
    if max((Midtern + Final + Homework):3) == max.Notlar:
        print("Congrats!" + v )
# Out:
#   File "<ipython-input-23-a7da36bbb085>", line 15
#     if max((Midtern + Final + Homework):3) == max.Notlar:
#                                        ^
# SyntaxError: invalid syntax

# %%
#Öğrenciler
Ogr1 = ["Duygu Irmak"]
Ogr2 = ["Deniz Doğru"]
Ogr3 = ["Ali Uslu"]
Ogr4 = ["Özge Sucu"]
Ogr5 = ["Mine Tuzcu"]




DictInformation = {Ogr1: "Duygu Irmak", Ogr2: "Deniz Doğru", Ogr3: "Ali Uslu", Ogr4: "Özge Sucu" 
               , Ogr5: "Mine Tuzcu"}

for v in DictInformation.values():
        print(v)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-409ac317acee> in <module>
#       9
#      10
# ---> 11 DictInformation = {Ogr1: "Duygu Irmak", Ogr2: "Deniz Doğru", Ogr3: "Ali Uslu", Ogr4: "Özge Sucu"
#      12                , Ogr5: "Mine Tuzcu"}
#      13
#
# TypeError: unhashable type: 'list'

# %%
Information = {"Duygu Irmak":  [80, 62, 75], "Deniz Doğru": [62, 78, 80], "Ali Uslu": [50, 62, 75], "Özge Sucu": [92, 88, 86], "Mine Tuzcu": [42, 67, 34]}

# %%
#Öğrenci Bilgileri
OgrList = ["Duygu Irmak", "Deniz Doğru", "Ali Uslu", "Özge Sucu" ,"Mine Tuzcu"]

NotList = [Midterm, Final, Homework]
Midterm = Float(input("Lütfen midterm puanınızı giriniz!"))
Final = Float(input("Lütfen final puanınızı giriniz!"))
Homework = Float(input("Lütfen homework puanınızı giriniz!"))


Ogr1 = ["Duygu Irmak"]
Ogr2 = ["Deniz Doğru"]
Ogr3 = ["Ali Uslu"]
Ogr4  = ["Özge Sucu"]
Ogr5  = ["Mine Tuzcu"]

# %%
M= int(input("Please enter a number: "))
F= int(input("Please enter a number: "))


if num < 0:  
  num *= -1  #num = num*-1
print("Result: ", num)

# %%
Not1 = [80, 62, 74] 
Not2 = [62, 78, 70]
Not3 = [50, 62, 74]
Not4 = [92, 68, 86]
Not5 = [42, 60, 33]

ogrenciler = ["Duygu Irmak", "Deniz Doğru", "Ali Uslu", "Özge Sucu", "Mine Tuzcu"]
notlar = [ortNot1, ortNot2, ortNot3, ortNot4, ortNot5]
list(zip(ogrenciler,notlar))[1]


#OrtalamaHesapla
ortNot1 = (80 + 62 + 74) / 3
print(ortNot1)
ortNot2 = (62 + 78 + 70) / 3
print(ortNot2)
ortNot3 = (50 + 62 + 74) / 3
print(ortNot3)
ortNot4 = (92 + 68 + 86) / 3
print(ortNot4)
ortNot5= (42 + 60 + 33) / 3
print(ortNot5)

Information = {"Duygu Irmak":ortNot1, "Deniz Doğru": ortNot2, "Ali Uslu": ortNot3, "Özge Sucu": ortNot4, 
               "Mine Tuzcu":ortNot5}



for i in range(1,5)
print(list(zip(ogrenciler,notlar))[i]
print("Ortalama1 puanı : " notlar[i]);
# Out:
#   File "<ipython-input-46-09b0d5335d88>", line 24
#     for i in range(1,5)
#                        ^
# SyntaxError: invalid syntax

# %%
#Öğrencilerden Midterm, Final ve Homework notlarını girmelerini isteriz
midterm = int(input("Midterm puanınızı giriniz : "))

final = int(input("Final puanınızı giriniz : "))

homework = int(input("Homework puanınızı giriniz : "))

notlar = range(midterm, final, homework)
ortalama = list(notlar)
ortNot = ((sum.ortalama)/3)



print(ortalama/3)


for i in notlar and 
    print(congrat)

# %%
#Öğrencilerden Midterm, Final ve Homework notlarını girmelerini isteriz
midterm = int(input("Midterm puanınızı giriniz : "))

final = int(input("Final puanınızı giriniz : "))

homework = int(input("Homework puanınızı giriniz : "))

notlar = range(midterm, final, homework)
ortalama = list(notlar)

return((midterm + final + homework)/3)
# Out:
#   File "<ipython-input-16-cfdb8fe96484>", line 11
#     def ortalamapuan()
#     ^
# IndentationError: unexpected indent

# %%
ogrencininNotlari = input("Midterm, Final ve Homework puanlarınızı virgül kullanarak giriniz : ")
print("Not Ortalamanız : {0}" .format(ogrencininNotlari))
ogrencininNotSayisi= ogrencininNotlari.split(",")
toplam = 0
for i in ogrencininNotSayisi:
    toplam = toplam + int(i)
    
print("Not Oralamanız : {0:.2f}" .format(toplam / len(ogrencininNotSayisi)))
# Out:
# Midterm, Final ve Homework puanlarınızı virgül kullanarak giriniz : 50
# Not Ortalamanız : 50
# Not Oralamanız : 50.00

# %%
#Öğrenciler ve notları
ogrenciler = ["Duygu Irmak", "Deniz Doğru", "Ali Uslu", "Özge Sucu", "Mine Tuzcu"]
notlar = ["ortNot1", "ortNot2", "ortNot3", "ortNot4", "ortNot5"]
list(zip(ogrenciler,notlar))

Information = {ortNot1: "Duygu Irmak", ortNot2: "Deniz Doğru", ortNot3: "Ali Uslu", ortNot4: "Özge Sucu" , ortNot5: "Mine Tuzcu"}


#Öğrencilerden Midterm, Final ve Homework notlarını girmelerini isteriz
midterm = int(input("Midterm puanınızı giriniz : "))

final = int(input("Final puanınızı giriniz : "))

homework = int(input("Homework puanınızı giriniz : "))

notlar = range(midterm, final, homework)
ortalama = list(notlar)
ortNot = sum(ortalama)/3
if ortNot < 50
    print("Bu dersten kaldınız!", name)

if num < 0:  
  num *= -1  #num = num*-1
print("Result: ", num)
# Out:
# Midterm puanınızı giriniz : 10
# Final puanınızı giriniz : 20
# Homework puanınızı giriniz : 30

# %%
ogrenciler = ["Duygu Irmak", "Deniz Doğru", "Ali Uslu", "Özge Sucu", "Mine Tuzcu"]
notlar = ["ortNot1", "ortNot2", "ortNot3", "ortNot4", "ortNot5"]
list(zip(ogrenciler,notlar))[1]

Information = {ortNot1: "Duygu Irmak", ortNot2: "Deniz Doğru", ortNot3: "Ali Uslu", ortNot4: "Özge Sucu" , 
               ortNot5: "Mine Tuzcu"}
# Out:
# ('Deniz Doğru', 'ortNot2')

# %%
#OrtalamaHesapla
ortNot1 = (80 + 62 + 74) / 3
print(ortNot1)
ortNot2 = (62 + 78 + 70) / 3
print(ortNot2)
ortNot3 = (50 + 62 + 74) / 3
print(ortNot3)
ortNot4 = (92 + 68 + 86) / 3
print(ortNot4)
ortNot5= (42 + 60 + 33) / 3
print(ortNot5)

Ortalamalar = [ortNot1, ortNot2, ortNot3, ortNot4, ortNot5]
Ortalamalar.sort(reverse=True)
Information = {"Duygu Irmak":ortNot1, "Deniz Doğru": ortNot2, "Ali Uslu": ortNot3, "Özge Sucu": ortNot4, 
               "Mine Tuzcu":ortNot5}
               
for i in Information[]:
    if i max
    print(Informatin)
# Out:
# 72.0
# 70.0
# 62.0
# 82.0
# 45.0
