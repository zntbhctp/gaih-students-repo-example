# %% [markdown]
# ZİNNET BAHÇETEPE / HOMEWORK-3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def primeFirst(deger):
    asal = True
    i = 2
    while (asal == True and i < deger):
        if deger % i == 0:
            asal = False
          
            return asal

# %%
for i in range(2, 500):
    asal = True
    for x in range(2, i):
        if i % x ==0:
            #print(i, "=", x, "*", i//x)
            asal = False
            i+=1
            break
        if asal:
            print(i, "asal sayıdır.")
# Out:
# 3 asal sayıdır.
# 5 asal sayıdır.
# 5 asal sayıdır.
# 5 asal sayıdır.
# 7 asal sayıdır.
# 7 asal sayıdır.
# 7 asal sayıdır.
# 7 asal sayıdır.
# 7 asal sayıdır.
# 9 asal sayıdır.
# 11 asal sayıdır.
# 11 asal sayıdır.
# 11 asal sayıdır.
# 11 asal sayıdır.
# 11 asal sayıdır.
# 11 asal sayıdır.
# 11 asal sayıdır.
# 11 asal sayıdır.
# 11 asal sayıdır.
# 13 asal sayıdır.
# 13 asal sayıdır.
# 13 asal sayıdır.
# 13 asal sayıdır.
# 13 asal sayıdır.
# 13 asal sayıdır.
# 13 asal sayıdır.
# 13 asal sayıdır.
# 13 asal sayıdır.
# 13 asal sayıdır.
# 13 asal sayıdır.
# 15 asal sayıdır.
# 17 asal sayıdır.
# 17 asal sayıdır.
# 17 asal sayıdır.
# 17 asal sayıdır.
# 17 asal sayıdır.
# 17 asal sayıdır.
# 17 asal sayıdır.
# 17 asal sayıdır.
# 17 asal sayıdır.
# 17 asal sayıdır.
# 17 asal sayıdır.
# 17 asal sayıdır.
# 17 asal sayıdır.
# 17 asal sayıdır.
# 17 asal sayıdır.
# 19 asal sayıdır.
# 19 asal sayıdır.
# 19 asal sayıdır.
# 19 asal sayıdır.
# 19 asal sayıdır.
# 19 asal sayıdır.
# 19 asal sayıdır.
# ...

# %%
def prime_first(sayı):
    asal = True
    for i in range(2, sayı):
        if sayı % i == 0:
            asal = False
            return(asal, "Sayı Asaldır")

# %%
asal = prime_first(7)
print(asal)
# Out:
# None

# %%
def prime_second(*args):
    asal = True
    ilksayi=1
    for i in range(2, sayı):
        if sayı % i == 0:
            asal = False
            print(sayı, "asaldır.")

# %%
def prime_secondzin(num):
    for i in range(2,int(num) and (500 < num < 1000)):
        if(int(num)%i==0):
            i+=1
             
if(i!=0):
    print(num, "Asal sayı değildir.")
else:
    print(num, "Asal sayıdır.")
# Out:
# 7 Asal sayıdır.
